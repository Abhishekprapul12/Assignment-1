# %% [markdown]
# Product collection

# %%
product=['Dress','Jeweleries','Sandals','Electronics','Groceries','Medicine']

# %%
product
# Out:
# ['Dress', 'Jeweleries', 'Sandals', 'Electronics', 'Groceries', 'Medicine']

# %%
print(type(product))
# Out:
# <class 'list'>

# %% [markdown]
# Creating a Sample Prodcut

# %%
Sample_product=("Korean pant",3500,"Dress")

# %% [markdown]
# printing second and last product

# %%
print('First_product:',product[1])
print('Last_product:',product[-1])
# Out:
# First_product: Jeweleries
# Last_product: Medicine

# %% [markdown]
# Add two new product to the list

# %%
product.append('Gifts')
product.append('FootWear')
print(product)
# Out:
# ['Dress', 'Jeweleries', 'Sandals', 'Electronics', 'Groceries', 'Medicine', 'Gifts', 'FootWear']

# %% [markdown]
# Converting Sample_product into list ,changing its price and converting back to the tuple
